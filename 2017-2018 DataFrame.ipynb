# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy import stats

# %%
demar = pd.read_csv("DemarDerozan.csv")
kyle = pd.read_csv("KyleLowry.csv")
anunoby = pd.read_csv("OGAnunoby.csv")
serge_ibaka = pd.read_csv("SergeIbaka.csv")
valanciunas = pd.read_csv("Valanciunas.csv")
pascal_siakam = pd.read_csv("PascalSiakam.csv")
jakob_poltl = pd.read_csv("Jakob _Pöltl .csv")
fred_vanvleet = pd.read_csv("Fred_vanvleet.csv")
delon_wright = pd.read_csv("DelonWright.csv")
cj_miles = pd.read_csv("CJMiles.csv")
norman_powell = pd.read_csv("NormanPowell.csv")
lucas_nogueira = pd.read_csv("LucasNogueira.csv")
lorenzo_brown = pd.read_csv("LorenzoBrown.csv")
malcolm_miller = pd.read_csv("MalcolmMiller.csv")

alfonzo_mckinnie = pd.read_csv("AlfonzoMcKinnie.csv")
bruno_cabaclo = pd.read_csv("BrunoCabaclo.csv")
nigel_hayes = pd.read_csv("NigelHayes.csv")

# %%
demar[['Date','3P']]
# Out:
#           Date   3P
# 0   2017-10-19  0.0
# 1   2017-10-21  0.0
# 2   2017-10-23  2.0
# 3   2017-10-25  0.0
# 4   2017-10-27  0.0
# ..         ...  ...
# 87  2018-04-27  0.0
# 88  2018-05-01  0.0
# 89  2018-05-03  0.0
# 90  2018-05-05  0.0
# 91  2018-05-07  0.0
#
# [92 rows x 2 columns]

# %%
demar.columns
# Out:
# Index(['Rk', 'G', 'Date', 'Age', 'Tm', 'Unnamed: 5', 'Opp', 'Unnamed: 7', 'GS',
#        'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-'],
#       dtype='object')

# %%
demar_df = demar.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
demar_df['Date'] = pd.to_datetime(demar_df["Date"], format="%Y-%m-%d")
demar_df.dtypes
# Out:
# Rk                     int64
# G                    float64
# Date          datetime64[ns]
# Age                    int64
# Unnamed: 5            object
# Opp                   object
# Unnamed: 7            object
# GS                    object
# 3P                   float64
# 3PA                  float64
# 3P%                  float64
# dtype: object

# %%
demar_df['Date2'] = demar_df['Date'].shift(+1)
demar_df['Time Rested'] = (demar_df['Date'] - demar_df['Date2']).dt.days
demar_df = demar_df.drop(columns=['Date2'])
demar_df = demar_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})
demar_df['Home vs Away'].fillna("Home",inplace=True)
demar_df['Time Rested'].fillna("N/A", inplace = True)

demar_df= demar_df.replace(to_replace = "@", value = "Away")
demar_df['Name'] = "Demar Derozan"
demar_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  3P%  \
# 0    1   1.0 2017-10-19   28         Home  CHI      W (+17)  1  0.0  0.0  NaN
# 1    2   2.0 2017-10-21   28         Home  PHI      W (+34)  1  0.0  1.0  0.0
# 2    3   3.0 2017-10-23   28         Away  SAS       L (-4)  1  2.0  5.0  0.4
# 3    4   4.0 2017-10-25   28         Away  GSW       L (-5)  1  0.0  0.0  NaN
# 4    5   5.0 2017-10-27   28         Away  LAL       W (+9)  1  0.0  2.0  0.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...  ...  ...
# 87   6   6.0 2018-04-27   28         Away  WAS      W (+10)  1  0.0  4.0  0.0
# 88   7   7.0 2018-05-01   28         Home  CLE       L (-1)  1  0.0  4.0  0.0
# 89   8   8.0 2018-05-03   28         Home  CLE      L (-18)  1  0.0  5.0  0.0
# 90   9   9.0 2018-05-05   28         Away  CLE       L (-2)  1  0.0  0.0  NaN
# 91  10  10.0 2018-05-07   28         Away  CLE      L (-35)  1  0.0  0.0  NaN
#
#    Time Rested           Name
# 0          N/A  Demar Derozan
# 1            2  Demar Derozan
# 2            2  Demar Derozan
# 3            2  Demar Derozan
# 4            2  Demar Derozan
# ..         ...            ...
# 87           2  Demar Derozan
# 88           4  Demar Derozan
# 89           2  Demar Derozan
# 90           2  Demar Derozan
# 91           2  Demar Derozan
#
# [92 rows x 13 columns]

# %%
# remove the columns we don't need 
kyle_df = kyle.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])

# change datatype of the Dates to datetime
kyle_df['Date'] = pd.to_datetime(kyle_df['Date'], format = "%Y-%m-%d")

# calculate the number of days in between game days
kyle_df['Date2'] = kyle_df['Date'].shift(+1)
kyle_df['Time Rested'] = (kyle_df['Date'] - kyle_df['Date2']).dt.days
kyle_df = kyle_df.drop(columns=['Date2'])


# rename the unnamed columns for better clarification
kyle_df = kyle_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
kyle_df['Home vs Away'].fillna("Home",inplace=True)
kyle_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
kyle_df= kyle_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
kyle_df['Name'] = "Kyle Lowry"
kyle_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P   3PA  \
# 0    1   1.0 2017-10-19   31         Home  CHI      W (+17)  1  1.0   3.0
# 1    2   2.0 2017-10-21   31         Home  PHI      W (+34)  1  4.0  10.0
# 2    3   3.0 2017-10-23   31         Away  SAS       L (-4)  1  2.0   8.0
# 3    4   4.0 2017-10-25   31         Away  GSW       L (-5)  1  1.0   8.0
# 4    5   5.0 2017-10-27   31         Away  LAL       W (+9)  1  3.0   7.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...   ...
# 87   6   6.0 2018-04-27   32         Away  WAS      W (+10)  1  3.0   7.0
# 88   7   7.0 2018-05-01   32         Home  CLE       L (-1)  1  3.0   6.0
# 89   8   8.0 2018-05-03   32         Home  CLE      L (-18)  1  3.0   6.0
# 90   9   9.0 2018-05-05   32         Away  CLE       L (-2)  1  4.0   8.0
# 91  10  10.0 2018-05-07   32         Away  CLE      L (-35)  1  1.0   4.0
#
#       3P% Time Rested        Name
# 0   0.333         N/A  Kyle Lowry
# 1   0.400           2  Kyle Lowry
# 2   0.250           2  Kyle Lowry
# 3   0.125           2  Kyle Lowry
# 4   0.429           2  Kyle Lowry
# ..    ...         ...         ...
# 87  0.429           2  Kyle Lowry
# 88  0.500           4  Kyle Lowry
# 89  0.500           2  Kyle Lowry
# 90  0.500           2  Kyle Lowry
# 91  0.250           2  Kyle Lowry
#
# [92 rows x 13 columns]

# %%
anunoby_df = anunoby.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
anunoby_df['Date'] = pd.to_datetime(anunoby['Date'], format = "%Y-%m-%d")
anunoby_df['Time Rested'] = kyle_df['Time Rested']


# rename the unnamed columns for better clarification
anunoby_df = anunoby_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
anunoby_df['Home vs Away'].fillna("Home",inplace=True)
anunoby_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
anunoby_df= anunoby_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
anunoby_df['Name'] = "OG Anunoby"
anunoby_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  \
# 0    1   1.0 2017-10-19   20         Home  CHI      W (+17)  0  1.0  3.0
# 1    2   2.0 2017-10-21   20         Home  PHI      W (+34)  0  1.0  2.0
# 2    3   3.0 2017-10-23   20         Away  SAS       L (-4)  0  0.0  2.0
# 3    4   4.0 2017-10-25   20         Away  GSW       L (-5)  0  2.0  4.0
# 4    5   5.0 2017-10-27   20         Away  LAL       W (+9)  0  1.0  3.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...  ...
# 87   6   6.0 2018-04-27   20         Away  WAS      W (+10)  1  1.0  2.0
# 88   7   7.0 2018-05-01   20         Home  CLE       L (-1)  1  1.0  3.0
# 89   8   8.0 2018-05-03   20         Home  CLE      L (-18)  1  1.0  3.0
# 90   9   9.0 2018-05-05   20         Away  CLE       L (-2)  1  4.0  7.0
# 91  10  10.0 2018-05-07   20         Away  CLE      L (-35)  1  0.0  1.0
#
#       3P% Time Rested        Name
# 0   0.333         N/A  OG Anunoby
# 1   0.500           2  OG Anunoby
# 2   0.000           2  OG Anunoby
# 3   0.500           2  OG Anunoby
# 4   0.333           2  OG Anunoby
# ..    ...         ...         ...
# 87  0.500           2  OG Anunoby
# 88  0.333           4  OG Anunoby
# 89  0.333           2  OG Anunoby
# 90  0.571           2  OG Anunoby
# 91  0.000           2  OG Anunoby
#
# [92 rows x 13 columns]

# %%
sergeibaka_df = serge_ibaka.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
sergeibaka_df['Date'] = pd.to_datetime(sergeibaka_df['Date'], format = "%Y-%m-%d")
sergeibaka_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
sergeibaka_df = sergeibaka_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
sergeibaka_df['Home vs Away'].fillna("Home",inplace=True)
sergeibaka_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
sergeibaka_df= sergeibaka_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
sergeibaka_df['Name'] = "Serge Ibaka"
sergeibaka_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  \
# 0    1   1.0 2017-10-19   28         Home  CHI      W (+17)  1  2.0  4.0
# 1    2   2.0 2017-10-21   28         Home  PHI      W (+34)  1  5.0  9.0
# 2    3   3.0 2017-10-23   28         Away  SAS       L (-4)  1  2.0  6.0
# 3    4   4.0 2017-10-25   28         Away  GSW       L (-5)  1  1.0  6.0
# 4    5   5.0 2017-10-27   28         Away  LAL       W (+9)  1  0.0  1.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...  ...
# 87   6   6.0 2018-04-27   28         Away  WAS      W (+10)  1  1.0  3.0
# 88   7   7.0 2018-05-01   28         Home  CLE       L (-1)  1  0.0  3.0
# 89   8   8.0 2018-05-03   28         Home  CLE      L (-18)  1  0.0  1.0
# 90   9   9.0 2018-05-05   28         Away  CLE       L (-2)  0  1.0  3.0
# 91  10  10.0 2018-05-07   28         Away  CLE      L (-35)  1  2.0  3.0
#
#       3P% Time Rested         Name
# 0   0.500         N/A  Serge Ibaka
# 1   0.556           2  Serge Ibaka
# 2   0.333           2  Serge Ibaka
# 3   0.167           2  Serge Ibaka
# 4   0.000           2  Serge Ibaka
# ..    ...         ...          ...
# 87  0.333           2  Serge Ibaka
# 88  0.000           4  Serge Ibaka
# 89  0.000           2  Serge Ibaka
# 90  0.333           2  Serge Ibaka
# 91  0.667           2  Serge Ibaka
#
# [92 rows x 13 columns]

# %%
valanciunas_df = valanciunas.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
valanciunas_df["Date"] = pd.to_datetime(valanciunas['Date'], format = "%Y-%m-%d")
valanciunas_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
valanciunas_df = valanciunas_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
valanciunas_df['Home vs Away'].fillna("Home",inplace=True)
valanciunas_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
valanciunas_df= valanciunas_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
valanciunas_df['Name'] = "Jonas Valanciunas"
valanciunas_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by:        GS   3P  \
# 0    1   1.0 2017-10-19   25         Home  CHI      W (+17)         1  0.0
# 1    2   2.0 2017-10-21   25         Home  PHI      W (+34)         1  0.0
# 2    3   NaN 2017-10-23   25         Away  SAS       L (-4)  Inactive  NaN
# 3    4   NaN 2017-10-25   25         Away  GSW       L (-5)  Inactive  NaN
# 4    5   NaN 2017-10-27   25         Away  LAL       W (+9)  Inactive  NaN
# ..  ..   ...        ...  ...          ...  ...          ...       ...  ...
# 87   6   6.0 2018-04-27   25         Away  WAS      W (+10)         1  0.0
# 88   7   7.0 2018-05-01   25         Home  CLE       L (-1)         1  0.0
# 89   8   8.0 2018-05-03   25         Home  CLE      L (-18)         1  0.0
# 90   9   9.0 2018-05-05   25         Away  CLE       L (-2)         1  0.0
# 91  10  10.0 2018-05-07   26         Away  CLE      L (-35)         0  0.0
#
#     3PA  3P% Time Rested               Name
# 0   1.0  0.0         N/A  Jonas Valanciunas
# 1   0.0  NaN           2  Jonas Valanciunas
# 2   NaN  NaN           2  Jonas Valanciunas
# 3   NaN  NaN           2  Jonas Valanciunas
# 4   NaN  NaN           2  Jonas Valanciunas
# ..  ...  ...         ...                ...
# 87  0.0  NaN           2  Jonas Valanciunas
# 88  1.0  0.0           4  Jonas Valanciunas
# 89  1.0  0.0           2  Jonas Valanciunas
# 90  0.0  NaN           2  Jonas Valanciunas
# 91  0.0  NaN           2  Jonas Valanciunas
#
# [92 rows x 13 columns]

# %%
pascalsiakam_df = pascal_siakam.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
pascalsiakam_df["Date"] = pd.to_datetime(pascalsiakam_df['Date'], format = "%Y-%m-%d")
pascalsiakam_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
pascalsiakam_df = pascalsiakam_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
pascalsiakam_df['Home vs Away'].fillna("Home",inplace=True)
pascalsiakam_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
pascalsiakam_df= pascalsiakam_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
pascalsiakam_df['Name'] = "Pascal Siakam"
pascalsiakam_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by:            GS  \
# 0    1   1.0 2017-10-19   23         Home  CHI      W (+17)             0
# 1    2   2.0 2017-10-21   23         Home  PHI      W (+34)             0
# 2    3   NaN 2017-10-23   23         Away  SAS       L (-4)  Did Not Play
# 3    4   3.0 2017-10-25   23         Away  GSW       L (-5)             1
# 4    5   4.0 2017-10-27   23         Away  LAL       W (+9)             1
# ..  ..   ...        ...  ...          ...  ...          ...           ...
# 87   6   6.0 2018-04-27   24         Away  WAS      W (+10)             0
# 88   7   7.0 2018-05-01   24         Home  CLE       L (-1)             0
# 89   8   8.0 2018-05-03   24         Home  CLE      L (-18)             0
# 90   9   9.0 2018-05-05   24         Away  CLE       L (-2)             0
# 91  10  10.0 2018-05-07   24         Away  CLE      L (-35)             0
#
#      3P  3PA    3P% Time Rested           Name
# 0   0.0  0.0    NaN         N/A  Pascal Siakam
# 1   0.0  2.0  0.000           2  Pascal Siakam
# 2   NaN  NaN    NaN           2  Pascal Siakam
# 3   2.0  3.0  0.667           2  Pascal Siakam
# 4   1.0  3.0  0.333           2  Pascal Siakam
# ..  ...  ...    ...         ...            ...
# 87  0.0  0.0    NaN           2  Pascal Siakam
# 88  1.0  1.0  1.000           4  Pascal Siakam
# 89  0.0  0.0    NaN           2  Pascal Siakam
# 90  0.0  0.0    NaN           2  Pascal Siakam
# 91  0.0  0.0    NaN           2  Pascal Siakam
#
# [92 rows x 13 columns]

# %%
jakob_poltl_df = jakob_poltl.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
jakob_poltl_df['Date'] = pd.to_datetime(jakob_poltl_df['Date'], format = "%Y-%m-%d")
jakob_poltl_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
jakob_poltl_df = jakob_poltl_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
jakob_poltl_df['Home vs Away'].fillna("Home",inplace=True)
jakob_poltl_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
jakob_poltl_df= jakob_poltl_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
jakob_poltl_df['Name'] = "Jakob Poltl"
jakob_poltl_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 0    1  1.0 2017-10-19   22         Home  CHI      W (+17)             0  0.0
# 1    2  2.0 2017-10-21   22         Home  PHI      W (+34)             0  0.0
# 2    3  3.0 2017-10-23   22         Away  SAS       L (-4)             0  0.0
# 3    4  4.0 2017-10-25   22         Away  GSW       L (-5)             0  0.0
# 4    5  5.0 2017-10-27   22         Away  LAL       W (+9)             0  0.0
# ..  ..  ...        ...  ...          ...  ...          ...           ...  ...
# 87   6  6.0 2018-04-27   22         Away  WAS      W (+10)             0  0.0
# 88   7  7.0 2018-05-01   22         Home  CLE       L (-1)             0  0.0
# 89   8  8.0 2018-05-03   22         Home  CLE      L (-18)             0  0.0
# 90   9  NaN 2018-05-05   22         Away  CLE       L (-2)  Did Not Play  NaN
# 91  10  9.0 2018-05-07   22         Away  CLE      L (-35)             0  0.0
#
#     3PA  3P% Time Rested         Name
# 0   0.0  NaN         N/A  Jakob Poltl
# 1   0.0  NaN           2  Jakob Poltl
# 2   0.0  NaN           2  Jakob Poltl
# 3   0.0  NaN           2  Jakob Poltl
# 4   0.0  NaN           2  Jakob Poltl
# ..  ...  ...         ...          ...
# 87  1.0  0.0           2  Jakob Poltl
# 88  0.0  NaN           4  Jakob Poltl
# 89  0.0  NaN           2  Jakob Poltl
# 90  NaN  NaN           2  Jakob Poltl
# 91  0.0  NaN           2  Jakob Poltl
#
# [92 rows x 13 columns]

# %%
fred_vanvleet_df = fred_vanvleet.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
fred_vanvleet_df['Date'] = pd.to_datetime(fred_vanvleet_df['Date'], format = "%Y-%m-%d")
fred_vanvleet_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
fred_vanvleet_df = fred_vanvleet_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
fred_vanvleet_df['Home vs Away'].fillna("Home",inplace=True)
fred_vanvleet_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
fred_vanvleet_df= fred_vanvleet_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
fred_vanvleet_df['Name'] = "Fred Vanvleet"
fred_vanvleet_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  \
# 0    1  1.0 2017-10-19   23         Home  CHI      W (+17)  0  0.0  2.0
# 1    2  2.0 2017-10-21   23         Home  PHI      W (+34)  0  1.0  4.0
# 2    3  3.0 2017-10-23   23         Away  SAS       L (-4)  0  1.0  2.0
# 3    4  4.0 2017-10-25   23         Away  GSW       L (-5)  0  0.0  0.0
# 4    5  5.0 2017-10-27   23         Away  LAL       W (+9)  0  0.0  1.0
# ..  ..  ...        ...  ...          ...  ...          ... ..  ...  ...
# 87   6  2.0 2018-04-27   24         Away  WAS      W (+10)  0  1.0  5.0
# 88   7  3.0 2018-05-01   24         Home  CLE       L (-1)  0  1.0  5.0
# 89   8  4.0 2018-05-03   24         Home  CLE      L (-18)  0  4.0  7.0
# 90   9  5.0 2018-05-05   24         Away  CLE       L (-2)  1  1.0  7.0
# 91  10  6.0 2018-05-07   24         Away  CLE      L (-35)  0  1.0  3.0
#
#       3P% Time Rested           Name
# 0   0.000         N/A  Fred Vanvleet
# 1   0.250           2  Fred Vanvleet
# 2   0.500           2  Fred Vanvleet
# 3     NaN           2  Fred Vanvleet
# 4   0.000           2  Fred Vanvleet
# ..    ...         ...            ...
# 87  0.200           2  Fred Vanvleet
# 88  0.200           4  Fred Vanvleet
# 89  0.571           2  Fred Vanvleet
# 90  0.143           2  Fred Vanvleet
# 91  0.333           2  Fred Vanvleet
#
# [92 rows x 13 columns]

# %%
delon_wright_df = delon_wright.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
delon_wright_df['Date'] = pd.to_datetime(delon_wright_df['Date'], format = "%Y-%m-%d")
delon_wright_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
delon_wright_df = delon_wright_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
delon_wright_df['Home vs Away'].fillna("Home",inplace=True)
delon_wright_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
delon_wright_df= delon_wright_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
delon_wright_df['Name'] = "Delon Wright"
delon_wright_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  \
# 0    1   1.0 2017-10-19   25         Home  CHI      W (+17)  0  0.0  1.0
# 1    2   2.0 2017-10-21   25         Home  PHI      W (+34)  0  1.0  6.0
# 2    3   3.0 2017-10-23   25         Away  SAS       L (-4)  0  0.0  3.0
# 3    4   4.0 2017-10-25   25         Away  GSW       L (-5)  0  0.0  4.0
# 4    5   5.0 2017-10-27   25         Away  LAL       W (+9)  0  0.0  2.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...  ...
# 87   6   6.0 2018-04-27   26         Away  WAS      W (+10)  0  0.0  0.0
# 88   7   7.0 2018-05-01   26         Home  CLE       L (-1)  0  1.0  2.0
# 89   8   8.0 2018-05-03   26         Home  CLE      L (-18)  0  1.0  2.0
# 90   9   9.0 2018-05-05   26         Away  CLE       L (-2)  0  0.0  1.0
# 91  10  10.0 2018-05-07   26         Away  CLE      L (-35)  0  0.0  1.0
#
#       3P% Time Rested          Name
# 0   0.000         N/A  Delon Wright
# 1   0.167           2  Delon Wright
# 2   0.000           2  Delon Wright
# 3   0.000           2  Delon Wright
# 4   0.000           2  Delon Wright
# ..    ...         ...           ...
# 87    NaN           2  Delon Wright
# 88  0.500           4  Delon Wright
# 89  0.500           2  Delon Wright
# 90  0.000           2  Delon Wright
# 91  0.000           2  Delon Wright
#
# [92 rows x 13 columns]

# %%
cj_miles_df = cj_miles.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
cj_miles_df['Date'] = pd.to_datetime(cj_miles_df['Date'], format = "%Y-%m-%d")
cj_miles_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
cj_miles_df = cj_miles_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
cj_miles_df['Home vs Away'].fillna("Home",inplace=True)
cj_miles_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
cj_miles_df= cj_miles_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
cj_miles_df['Name'] = "CJ Miles"
cj_miles_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  \
# 0    1   1.0 2017-10-19   30         Home  CHI      W (+17)  0  6.0  9.0
# 1    2   2.0 2017-10-21   30         Home  PHI      W (+34)  0  1.0  6.0
# 2    3   3.0 2017-10-23   30         Away  SAS       L (-4)  0  3.0  7.0
# 3    4   4.0 2017-10-25   30         Away  GSW       L (-5)  0  2.0  8.0
# 4    5   5.0 2017-10-27   30         Away  LAL       W (+9)  0  2.0  7.0
# ..  ..   ...        ...  ...          ...  ...          ... ..  ...  ...
# 87   6   6.0 2018-04-27   31         Away  WAS      W (+10)  0  1.0  3.0
# 88   7   7.0 2018-05-01   31         Home  CLE       L (-1)  0  2.0  3.0
# 89   8   8.0 2018-05-03   31         Home  CLE      L (-18)  0  2.0  2.0
# 90   9   9.0 2018-05-05   31         Away  CLE       L (-2)  0  3.0  7.0
# 91  10  10.0 2018-05-07   31         Away  CLE      L (-35)  1  0.0  2.0
#
#       3P% Time Rested      Name
# 0   0.667         N/A  CJ Miles
# 1   0.167           2  CJ Miles
# 2   0.429           2  CJ Miles
# 3   0.250           2  CJ Miles
# 4   0.286           2  CJ Miles
# ..    ...         ...       ...
# 87  0.333           2  CJ Miles
# 88  0.667           4  CJ Miles
# 89  1.000           2  CJ Miles
# 90  0.429           2  CJ Miles
# 91  0.000           2  CJ Miles
#
# [92 rows x 13 columns]

# %%
norman_powell_df= norman_powell.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
norman_powell_df['Date'] = pd.to_datetime(norman_powell_df['Date'], format = "%Y-%m-%d")
norman_powell_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
norman_powell_df = norman_powell_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
norman_powell_df['Home vs Away'].fillna("Home",inplace=True)
norman_powell_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
norman_powell_df= norman_powell_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
norman_powell_df['Name'] = "Norman Powell"
norman_powell_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 0    1  1.0 2017-10-19   24         Home  CHI      W (+17)             1  3.0
# 1    2  2.0 2017-10-21   24         Home  PHI      W (+34)             1  0.0
# 2    3  3.0 2017-10-23   24         Away  SAS       L (-4)             1  0.0
# 3    4  4.0 2017-10-25   24         Away  GSW       L (-5)             1  0.0
# 4    5  5.0 2017-10-27   24         Away  LAL       W (+9)             1  0.0
# ..  ..  ...        ...  ...          ...  ...          ...           ...  ...
# 87   6  NaN 2018-04-27   24         Away  WAS      W (+10)  Did Not Play  NaN
# 88   7  NaN 2018-05-01   24         Home  CLE       L (-1)  Did Not Play  NaN
# 89   8  5.0 2018-05-03   24         Home  CLE      L (-18)             0  0.0
# 90   9  NaN 2018-05-05   24         Away  CLE       L (-2)  Did Not Play  NaN
# 91  10  6.0 2018-05-07   24         Away  CLE      L (-35)             0  0.0
#
#     3PA  3P% Time Rested           Name
# 0   6.0  0.5         N/A  Norman Powell
# 1   1.0  0.0           2  Norman Powell
# 2   3.0  0.0           2  Norman Powell
# 3   1.0  0.0           2  Norman Powell
# 4   3.0  0.0           2  Norman Powell
# ..  ...  ...         ...            ...
# 87  NaN  NaN           2  Norman Powell
# 88  NaN  NaN           4  Norman Powell
# 89  1.0  0.0           2  Norman Powell
# 90  NaN  NaN           2  Norman Powell
# 91  1.0  0.0           2  Norman Powell
#
# [92 rows x 13 columns]

# %%
lucas_nogeira_df = norman_powell.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
lucas_nogeira_df['Date'] = pd.to_datetime(lucas_nogeira_df['Date'], format = "%Y-%m-%d")
lucas_nogeira_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
lucas_nogeira_df = lucas_nogeira_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
lucas_nogeira_df['Home vs Away'].fillna("Home",inplace=True)
lucas_nogeira_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
lucas_nogeira_df= lucas_nogeira_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
lucas_nogeira_df['Name'] = "Lucas Nogiera"
lucas_nogeira_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 0    1  1.0 2017-10-19   24         Home  CHI      W (+17)             1  3.0
# 1    2  2.0 2017-10-21   24         Home  PHI      W (+34)             1  0.0
# 2    3  3.0 2017-10-23   24         Away  SAS       L (-4)             1  0.0
# 3    4  4.0 2017-10-25   24         Away  GSW       L (-5)             1  0.0
# 4    5  5.0 2017-10-27   24         Away  LAL       W (+9)             1  0.0
# ..  ..  ...        ...  ...          ...  ...          ...           ...  ...
# 87   6  NaN 2018-04-27   24         Away  WAS      W (+10)  Did Not Play  NaN
# 88   7  NaN 2018-05-01   24         Home  CLE       L (-1)  Did Not Play  NaN
# 89   8  5.0 2018-05-03   24         Home  CLE      L (-18)             0  0.0
# 90   9  NaN 2018-05-05   24         Away  CLE       L (-2)  Did Not Play  NaN
# 91  10  6.0 2018-05-07   24         Away  CLE      L (-35)             0  0.0
#
#     3PA  3P% Time Rested           Name
# 0   6.0  0.5         N/A  Lucas Nogiera
# 1   1.0  0.0           2  Lucas Nogiera
# 2   3.0  0.0           2  Lucas Nogiera
# 3   1.0  0.0           2  Lucas Nogiera
# 4   3.0  0.0           2  Lucas Nogiera
# ..  ...  ...         ...            ...
# 87  NaN  NaN           2  Lucas Nogiera
# 88  NaN  NaN           4  Lucas Nogiera
# 89  1.0  0.0           2  Lucas Nogiera
# 90  NaN  NaN           2  Lucas Nogiera
# 91  1.0  0.0           2  Lucas Nogiera
#
# [92 rows x 13 columns]

# %%
lorenzo_brown_df = lorenzo_brown.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
lorenzo_brown_df['Date'] = pd.to_datetime(lorenzo_brown_df['Date'], format = "%Y-%m-%d")
lorenzo_brown_df['Time Rested'] = kyle_df['Time Rested']

# rename the unnamed columns for better clarification
lorenzo_brown_df = lorenzo_brown_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
lorenzo_brown_df['Home vs Away'].fillna("Home",inplace=True)
lorenzo_brown_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
lorenzo_brown_df= lorenzo_brown_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
lorenzo_brown_df['Name'] = "Lorenzo Brown"
lorenzo_brown_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 0    1  NaN 2017-10-19   27         Home  CHI      W (+17)      Inactive  NaN
# 1    2  NaN 2017-10-21   27         Home  PHI      W (+34)      Inactive  NaN
# 2    3  NaN 2017-10-23   27         Away  SAS       L (-4)      Inactive  NaN
# 3    4  NaN 2017-10-25   27         Away  GSW       L (-5)      Inactive  NaN
# 4    5  NaN 2017-10-27   27         Away  LAL       W (+9)      Inactive  NaN
# ..  ..  ...        ...  ...          ...  ...          ...           ...  ...
# 87   6  NaN 2018-04-27   27         Away  WAS      W (+10)  Did Not Play  NaN
# 88   7  NaN 2018-05-01   27         Home  CLE       L (-1)  Did Not Play  NaN
# 89   8  3.0 2018-05-03   27         Home  CLE      L (-18)             0  1.0
# 90   9  NaN 2018-05-05   27         Away  CLE       L (-2)  Did Not Play  NaN
# 91  10  4.0 2018-05-07   27         Away  CLE      L (-35)             0  0.0
#
#     3PA  3P% Time Rested           Name
# 0   NaN  NaN         N/A  Lorenzo Brown
# 1   NaN  NaN           2  Lorenzo Brown
# 2   NaN  NaN           2  Lorenzo Brown
# 3   NaN  NaN           2  Lorenzo Brown
# 4   NaN  NaN           2  Lorenzo Brown
# ..  ...  ...         ...            ...
# 87  NaN  NaN           2  Lorenzo Brown
# 88  NaN  NaN           4  Lorenzo Brown
# 89  2.0  0.5           2  Lorenzo Brown
# 90  NaN  NaN           2  Lorenzo Brown
# 91  0.0  NaN           2  Lorenzo Brown
#
# [92 rows x 13 columns]

# %%
malcolm_miller_df = malcolm_miller.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
malcolm_miller_df['Date'] = pd.to_datetime(malcolm_miller_df['Date'], format = "%Y-%m-%d")
malcolm_miller_df['Date2'] = malcolm_miller_df['Date'].shift(+1)
malcolm_miller_df['Time Rested'] = (malcolm_miller_df['Date'] - malcolm_miller_df['Date2']).dt.days
malcolm_miller_df = malcolm_miller_df.drop(columns=['Date2'])


# rename the unnamed columns for better clarification
malcolm_miller_df = malcolm_miller_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
malcolm_miller_df['Home vs Away'].fillna("Home",inplace=True)
malcolm_miller_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
malcolm_miller_df= malcolm_miller_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
malcolm_miller_df['Name'] = "Malcolm Miller"
malcolm_miller_df
# Out:
#     Rk   G       Date  Age Home vs Away  Opp Win/Loss by:            GS  3P  \
# 0    1 NaN 2017-10-19   24         Home  CHI      W (+17)      Inactive NaN
# 1    2 NaN 2017-10-21   24         Home  PHI      W (+34)      Inactive NaN
# 2    3 NaN 2017-10-23   24         Away  SAS       L (-4)      Inactive NaN
# 3    4 NaN 2017-10-25   24         Away  GSW       L (-5)      Inactive NaN
# 4    5 NaN 2017-10-27   24         Away  LAL       W (+9)      Inactive NaN
# ..  ..  ..        ...  ...          ...  ...          ...           ...  ..
# 77  78 NaN 2018-04-04   25         Home  BOS      W (+18)      Inactive NaN
# 78  79 NaN 2018-04-06   25         Home  IND      W (+19)      Inactive NaN
# 79  80 NaN 2018-04-08   25         Home  ORL      W (+11)      Inactive NaN
# 80  81 NaN 2018-04-09   25         Away  DET      W (+10)  Did Not Play NaN
# 81  82 NaN 2018-04-11   25         Away  MIA       L (-7)      Inactive NaN
#
#     3PA  3P% Time Rested            Name
# 0   NaN  NaN         N/A  Malcolm Miller
# 1   NaN  NaN           2  Malcolm Miller
# 2   NaN  NaN           2  Malcolm Miller
# 3   NaN  NaN           2  Malcolm Miller
# 4   NaN  NaN           2  Malcolm Miller
# ..  ...  ...         ...             ...
# 77  NaN  NaN           1  Malcolm Miller
# 78  NaN  NaN           2  Malcolm Miller
# 79  NaN  NaN           2  Malcolm Miller
# 80  NaN  NaN           1  Malcolm Miller
# 81  NaN  NaN           2  Malcolm Miller
#
# [82 rows x 13 columns]

# %%
alfonzo_mckinnie_df = alfonzo_mckinnie.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
alfonzo_mckinnie_df['Date'] = pd.to_datetime(alfonzo_mckinnie_df['Date'], format = "%Y-%m-%d")
alfonzo_mckinnie_df['Date2'] = alfonzo_mckinnie_df['Date'].shift(+1)
alfonzo_mckinnie_df['Time Rested'] = (alfonzo_mckinnie_df['Date'] - alfonzo_mckinnie_df['Date2']).dt.days
alfonzo_mckinnie_df = alfonzo_mckinnie_df.drop(columns=['Date2'])

# rename the unnamed columns for better clarification
alfonzo_mckinnie_df = alfonzo_mckinnie_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
alfonzo_mckinnie_df['Home vs Away'].fillna("Home",inplace=True)
alfonzo_mckinnie_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
alfonzo_mckinnie_df= alfonzo_mckinnie_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
alfonzo_mckinnie_df['Name'] = "Alfonzo Mckinnie"
alfonzo_mckinnie_df
# Out:
#     Rk     G       Date  Age Home vs Away  Opp Win/Loss by:            GS  \
# 0    1   1.0 2017-10-19   25         Home  CHI      W (+17)             0
# 1    2   NaN 2017-10-21   25         Home  PHI      W (+34)      Inactive
# 2    3   NaN 2017-10-23   25         Away  SAS       L (-4)  Did Not Play
# 3    4   NaN 2017-10-25   25         Away  GSW       L (-5)  Did Not Play
# 4    5   NaN 2017-10-27   25         Away  LAL       W (+9)  Did Not Play
# ..  ..   ...        ...  ...          ...  ...          ...           ...
# 77  78   NaN 2018-04-04   25         Home  BOS      W (+18)      Inactive
# 78  79   NaN 2018-04-06   25         Home  IND      W (+19)      Inactive
# 79  80   NaN 2018-04-08   25         Home  ORL      W (+11)      Inactive
# 80  81  14.0 2018-04-09   25         Away  DET      W (+10)             0
# 81  82   NaN 2018-04-11   25         Away  MIA       L (-7)      Inactive
#
#      3P  3PA  3P% Time Rested              Name
# 0   0.0  0.0  NaN         N/A  Alfonzo Mckinnie
# 1   NaN  NaN  NaN           2  Alfonzo Mckinnie
# 2   NaN  NaN  NaN           2  Alfonzo Mckinnie
# 3   NaN  NaN  NaN           2  Alfonzo Mckinnie
# 4   NaN  NaN  NaN           2  Alfonzo Mckinnie
# ..  ...  ...  ...         ...               ...
# 77  NaN  NaN  NaN           1  Alfonzo Mckinnie
# 78  NaN  NaN  NaN           2  Alfonzo Mckinnie
# 79  NaN  NaN  NaN           2  Alfonzo Mckinnie
# 80  0.0  1.0  0.0           1  Alfonzo Mckinnie
# 81  NaN  NaN  NaN           2  Alfonzo Mckinnie
#
# [82 rows x 13 columns]

# %%
# take only the games where player played on the RAPTORS
bruno_cabaclo_df = bruno_cabaclo.loc[bruno_cabaclo['Tm'] == "TOR", :]

# Drop the unwanted columns
bruno_cabaclo_df = bruno_cabaclo_df.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm'])
bruno_cabaclo_df['Date'] = pd.to_datetime(bruno_cabaclo_df['Date'], format = "%Y-%m-%d")
bruno_cabaclo_df['Date2'] = bruno_cabaclo_df['Date'].shift(+1)
bruno_cabaclo_df['Time Rested'] = (bruno_cabaclo_df['Date'] - bruno_cabaclo_df['Date2']).dt.days
bruno_cabaclo_df = bruno_cabaclo_df.drop(columns=['Date2'])

# rename the unnamed columns for better clarification
bruno_cabaclo_df = bruno_cabaclo_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
bruno_cabaclo_df['Home vs Away'].fillna("Home",inplace=True)
bruno_cabaclo_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
bruno_cabaclo_df= bruno_cabaclo_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
bruno_cabaclo_df['Name'] = "Bruno Cabaclo"
bruno_cabaclo_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 0    1  NaN 2017-10-19   22         Home  CHI      W (+17)      Inactive  NaN
# 1    2  1.0 2017-10-21   22         Home  PHI      W (+34)             0  0.0
# 2    3  NaN 2017-10-23   22         Away  SAS       L (-4)  Did Not Play  NaN
# 3    4  NaN 2017-10-25   22         Away  GSW       L (-5)  Did Not Play  NaN
# 4    5  NaN 2017-10-27   22         Away  LAL       W (+9)  Did Not Play  NaN
# 5    6  2.0 2017-10-30   22         Away  POR      W (+14)             0  0.0
# 6    7  NaN 2017-11-01   22         Away  DEN      L (-18)      Inactive  NaN
# 7    8  NaN 2017-11-03   22         Away  UTA       W (+9)  Did Not Play  NaN
# 8    9  NaN 2017-11-05   22         Home  WAS      L (-11)  Did Not Play  NaN
# 9   10  NaN 2017-11-07   22         Home  CHI       W (+5)      Inactive  NaN
# 10  11  NaN 2017-11-09   22         Home  NOP       W (+4)      Inactive  NaN
# 11  12  NaN 2017-11-12   22         Away  BOS       L (-1)      Inactive  NaN
# 12  13  NaN 2017-11-14   22         Away  HOU      W (+16)      Inactive  NaN
# 13  14  NaN 2017-11-15   22         Away  NOP       W (+9)      Inactive  NaN
# 14  15  NaN 2017-11-17   22         Home  NYK      W (+23)  Did Not Play  NaN
# 15  16  NaN 2017-11-19   22         Home  WAS       W (+9)  Did Not Play  NaN
# 16  17  NaN 2017-11-22   22         Away  NYK       L (-8)      Inactive  NaN
# 17  18  NaN 2017-11-24   22         Away  IND       L (-3)      Inactive  NaN
# 18  19  NaN 2017-11-25   22         Away  ATL      W (+34)      Inactive  NaN
# 19  20  NaN 2017-11-29   22         Home  CHO      W (+13)      Inactive  NaN
# 20  21  NaN 2017-12-01   22         Home  IND       W (+5)      Inactive  NaN
# 21  22  NaN 2017-12-05   22         Home  PHO      W (+13)      Inactive  NaN
# 22  23  NaN 2017-12-08   22         Away  MEM       W (+9)      Inactive  NaN
# 23  24  NaN 2017-12-10   22         Away  SAC      W (+15)      Inactive  NaN
# 24  25  NaN 2017-12-11   22         Away  LAC       L (-5)      Inactive  NaN
# 25  26  NaN 2017-12-13   22         Away  PHO       W (+6)      Inactive  NaN
# 26  27  NaN 2017-12-15   22         Home  BRK      W (+33)      Inactive  NaN
# 27  28  NaN 2017-12-17   22         Home  SAC      W (+15)      Inactive  NaN
# 28  29  NaN 2017-12-20   22         Away  CHO      W (+18)      Inactive  NaN
# 29  30  NaN 2017-12-21   22         Away  PHI       W (+5)      Inactive  NaN
# 30  31  NaN 2017-12-23   22         Home  PHI      W (+16)      Inactive  NaN
# 31  32  NaN 2017-12-26   22         Away  DAL       L (-5)      Inactive  NaN
# 32  33  NaN 2017-12-27   22         Away  OKC      L (-17)      Inactive  NaN
# 33  34  NaN 2017-12-29   22         Home  ATL      W (+13)  Did Not Play  NaN
# 34  35  NaN 2018-01-01   22         Home  MIL       W (+4)      Inactive  NaN
# 35  36  NaN 2018-01-03   22         Away  CHI       W (+9)      Inactive  NaN
# 36  37  NaN 2018-01-05   22         Away  MIL      W (+19)      Inactive  NaN
# 37  38  NaN 2018-01-08   22         Away  BRK       W (+1)      Inactive  NaN
# 38  39  NaN 2018-01-09   22         Home  MIA       L (-1)      Inactive  NaN
# 39  40  NaN 2018-01-11   22         Home  CLE      W (+34)      Inactive  NaN
# 40  41  NaN 2018-01-13   22         Home  GSW       L (-2)      Inactive  NaN
# 41  42  NaN 2018-01-15   22         Away  PHI       L (-6)      Inactive  NaN
# 42  43  NaN 2018-01-17   22         Home  DET       W (+5)      Inactive  NaN
# 43  44  NaN 2018-01-19   22         Home  SAS       W (+3)      Inactive  NaN
# 44  45  NaN 2018-01-20   22         Away  MIN       L (-6)      Inactive  NaN
# 45  46  NaN 2018-01-24   22         Away  ATL      W (+15)      Inactive  NaN
# 46  47  NaN 2018-01-26   22         Home  UTA       L (-4)      Inactive  NaN
# 47  48  NaN 2018-01-28   22         Home  LAL      W (+12)      Inactive  NaN
# 48  49  NaN 2018-01-30   22         Home  MIN       W (+5)      Inactive  NaN
# 49  50  NaN 2018-02-01   22         Away  WAS       L (-3)      Inactive  NaN
# 50  51  NaN 2018-02-02   22         Home  POR      W (+25)      Inactive  NaN
# 51  52  NaN 2018-02-04   22         Home  MEM      W (+15)      Inactive  NaN
# 52  53  NaN 2018-02-06   22         Home  BOS      W (+20)      Inactive  NaN
# 53  54  NaN 2018-02-08   22         Home  NYK      W (+25)      Inactive  NaN
#
#     3PA  3P% Time Rested           Name
# 0   NaN  NaN         N/A  Bruno Cabaclo
# 1   2.0  0.0           2  Bruno Cabaclo
# 2   NaN  NaN           2  Bruno Cabaclo
# 3   NaN  NaN           2  Bruno Cabaclo
# 4   NaN  NaN           2  Bruno Cabaclo
# 5   0.0  NaN           3  Bruno Cabaclo
# 6   NaN  NaN           2  Bruno Cabaclo
# 7   NaN  NaN           2  Bruno Cabaclo
# 8   NaN  NaN           2  Bruno Cabaclo
# 9   NaN  NaN           2  Bruno Cabaclo
# 10  NaN  NaN           2  Bruno Cabaclo
# 11  NaN  NaN           3  Bruno Cabaclo
# 12  NaN  NaN           2  Bruno Cabaclo
# 13  NaN  NaN           1  Bruno Cabaclo
# 14  NaN  NaN           2  Bruno Cabaclo
# 15  NaN  NaN           2  Bruno Cabaclo
# 16  NaN  NaN           3  Bruno Cabaclo
# 17  NaN  NaN           2  Bruno Cabaclo
# 18  NaN  NaN           1  Bruno Cabaclo
# 19  NaN  NaN           4  Bruno Cabaclo
# 20  NaN  NaN           2  Bruno Cabaclo
# 21  NaN  NaN           4  Bruno Cabaclo
# 22  NaN  NaN           3  Bruno Cabaclo
# 23  NaN  NaN           2  Bruno Cabaclo
# 24  NaN  NaN           1  Bruno Cabaclo
# 25  NaN  NaN           2  Bruno Cabaclo
# 26  NaN  NaN           2  Bruno Cabaclo
# 27  NaN  NaN           2  Bruno Cabaclo
# 28  NaN  NaN           3  Bruno Cabaclo
# 29  NaN  NaN           1  Bruno Cabaclo
# 30  NaN  NaN           2  Bruno Cabaclo
# 31  NaN  NaN           3  Bruno Cabaclo
# 32  NaN  NaN           1  Bruno Cabaclo
# 33  NaN  NaN           2  Bruno Cabaclo
# 34  NaN  NaN           3  Bruno Cabaclo
# 35  NaN  NaN           2  Bruno Cabaclo
# 36  NaN  NaN           2  Bruno Cabaclo
# 37  NaN  NaN           3  Bruno Cabaclo
# 38  NaN  NaN           1  Bruno Cabaclo
# 39  NaN  NaN           2  Bruno Cabaclo
# 40  NaN  NaN           2  Bruno Cabaclo
# 41  NaN  NaN           2  Bruno Cabaclo
# 42  NaN  NaN           2  Bruno Cabaclo
# 43  NaN  NaN           2  Bruno Cabaclo
# 44  NaN  NaN           1  Bruno Cabaclo
# 45  NaN  NaN           4  Bruno Cabaclo
# 46  NaN  NaN           2  Bruno Cabaclo
# 47  NaN  NaN           2  Bruno Cabaclo
# 48  NaN  NaN           2  Bruno Cabaclo
# 49  NaN  NaN           2  Bruno Cabaclo
# 50  NaN  NaN           1  Bruno Cabaclo
# 51  NaN  NaN           2  Bruno Cabaclo
# 52  NaN  NaN           2  Bruno Cabaclo
# 53  NaN  NaN           2  Bruno Cabaclo

# %%
# take only the games where player played on the RAPTORS
nigel_hayes_df = nigel_hayes.loc[nigel_hayes['Tm'] == "TOR", :]

# Drop the unwanted columns
nigel_hayes_df = nigel_hayes_df.drop(columns = ['FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%','Tm'])
nigel_hayes_df['Date'] = pd.to_datetime(nigel_hayes_df['Date'], format = "%Y-%m-%d")
nigel_hayes_df['Date2'] = nigel_hayes_df['Date'].shift(+1)
nigel_hayes_df['Time Rested'] = (nigel_hayes_df['Date'] - nigel_hayes_df['Date2']).dt.days
nigel_hayes_df = nigel_hayes_df.drop(columns=['Date2'])

# rename the unnamed columns for better clarification
nigel_hayes_df = nigel_hayes_df.rename(columns = {"Unnamed: 5": "Home vs Away", "Unnamed: 7": "Win/Loss by:"})

# replace the NaN values in the speicifc columns 
nigel_hayes_df['Home vs Away'].fillna("Home",inplace=True)
nigel_hayes_df['Time Rested'].fillna("N/A", inplace = True)

# replace the value in the column
nigel_hayes_df= nigel_hayes_df.replace(to_replace = "@", value = "Away")

# Input player name to the end of the dataFrame
nigel_hayes_df['Name'] = "Nigel Hayes"
nigel_hayes_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:            GS   3P  \
# 4    5  NaN 2018-03-06   23         Home  ATL      W (+16)      Inactive  NaN
# 5    6  NaN 2018-03-07   23         Away  DET       W (+2)  Did Not Play  NaN
# 6    7  NaN 2018-03-09   23         Home  HOU       W (+3)  Did Not Play  NaN
# 7    8  3.0 2018-03-11   23         Away  NYK      W (+26)             0  2.0
# 8    9  4.0 2018-03-13   23         Away  BRK      W (+14)             0  0.0
# 9   10  NaN 2018-03-15   23         Away  IND       W (+7)  Did Not Play  NaN
# 10  11  NaN 2018-03-16   23         Home  DAL       W (+7)  Did Not Play  NaN
# 11  12  NaN 2018-03-18   23         Home  OKC       L (-7)      Inactive  NaN
# 12  13  NaN 2018-03-20   23         Away  ORL       W (+7)      Inactive  NaN
# 13  14  NaN 2018-03-21   23         Away  CLE       L (-3)      Inactive  NaN
# 14  15  NaN 2018-03-23   23         Home  BRK       W (+4)      Inactive  NaN
# 15  16  NaN 2018-03-25   23         Home  LAC      L (-11)      Inactive  NaN
#
#     3PA  3P% Time Rested         Name
# 4   NaN  NaN         N/A  Nigel Hayes
# 5   NaN  NaN           1  Nigel Hayes
# 6   NaN  NaN           2  Nigel Hayes
# 7   2.0  1.0           2  Nigel Hayes
# 8   0.0  NaN           2  Nigel Hayes
# 9   NaN  NaN           2  Nigel Hayes
# 10  NaN  NaN           1  Nigel Hayes
# 11  NaN  NaN           2  Nigel Hayes
# 12  NaN  NaN           2  Nigel Hayes
# 13  NaN  NaN           1  Nigel Hayes
# 14  NaN  NaN           2  Nigel Hayes
# 15  NaN  NaN           2  Nigel Hayes

# %%
#List of Dataframes
pdList = [demar_df, kyle_df, anunoby_df, sergeibaka_df, valanciunas_df, pascalsiakam_df, jakob_poltl_df, fred_vanvleet_df, delon_wright_df, cj_miles_df, norman_powell_df, lucas_nogeira_df, lorenzo_brown_df, malcolm_miller_df, alfonzo_mckinnie_df, bruno_cabaclo_df, nigel_hayes_df]
new_df = pd.concat(pdList)
new_df
# Out:
#     Rk    G       Date  Age Home vs Away  Opp Win/Loss by:        GS   3P  \
# 0    1  1.0 2017-10-19   28         Home  CHI      W (+17)         1  0.0
# 1    2  2.0 2017-10-21   28         Home  PHI      W (+34)         1  0.0
# 2    3  3.0 2017-10-23   28         Away  SAS       L (-4)         1  2.0
# 3    4  4.0 2017-10-25   28         Away  GSW       L (-5)         1  0.0
# 4    5  5.0 2017-10-27   28         Away  LAL       W (+9)         1  0.0
# ..  ..  ...        ...  ...          ...  ...          ...       ...  ...
# 11  12  NaN 2018-03-18   23         Home  OKC       L (-7)  Inactive  NaN
# 12  13  NaN 2018-03-20   23         Away  ORL       W (+7)  Inactive  NaN
# 13  14  NaN 2018-03-21   23         Away  CLE       L (-3)  Inactive  NaN
# 14  15  NaN 2018-03-23   23         Home  BRK       W (+4)  Inactive  NaN
# 15  16  NaN 2018-03-25   23         Home  LAC      L (-11)  Inactive  NaN
#
#     3PA  3P% Time Rested           Name
# 0   0.0  NaN         N/A  Demar Derozan
# 1   1.0  0.0           2  Demar Derozan
# 2   5.0  0.4           2  Demar Derozan
# 3   0.0  NaN           2  Demar Derozan
# 4   2.0  0.0           2  Demar Derozan
# ..  ...  ...         ...            ...
# 11  NaN  NaN           2    Nigel Hayes
# 12  NaN  NaN           2    Nigel Hayes
# 13  NaN  NaN           1    Nigel Hayes
# 14  NaN  NaN           2    Nigel Hayes
# 15  NaN  NaN           2    Nigel Hayes
#
# [1426 rows x 13 columns]

# %%
#Save as csv file 
new_df.to_csv("2017-18 Concat Dataframe.csv", encoding = 'utf-8', index = False, header= True)

# %%
pdList = [demar_df, kyle_df, anunoby_df, sergeibaka_df, valanciunas_df, pascalsiakam_df, jakob_poltl_df, fred_vanvleet_df, delon_wright_df, cj_miles_df, norman_powell_df, lucas_nogeira_df, lorenzo_brown_df, malcolm_miller_df, alfonzo_mckinnie_df, bruno_cabaclo_df, nigel_hayes_df]

# %%
new_df['Time Rested'] = new_df['Time Rested'].replace(to_replace = 9, value = '6+')

# %%
new_df.head()
# Out:
#    Rk    G       Date  Age Home vs Away  Opp Win/Loss by: GS   3P  3PA  3P%  \
# 0   1  1.0 2017-10-19   28         Home  CHI      W (+17)  1  0.0  0.0  NaN
# 1   2  2.0 2017-10-21   28         Home  PHI      W (+34)  1  0.0  1.0  0.0
# 2   3  3.0 2017-10-23   28         Away  SAS       L (-4)  1  2.0  5.0  0.4
# 3   4  4.0 2017-10-25   28         Away  GSW       L (-5)  1  0.0  0.0  NaN
# 4   5  5.0 2017-10-27   28         Away  LAL       W (+9)  1  0.0  2.0  0.0
#
#   Time Rested           Name
# 0         N/A  Demar Derozan
# 1           2  Demar Derozan
# 2           2  Demar Derozan
# 3           2  Demar Derozan
# 4           2  Demar Derozan

# %%
players_name_group = new_df.groupby('Name')
players_name_group.sum()['3P']
# Out:
# Name
# Alfonzo Mckinnie       3.0
# Bruno Cabaclo          0.0
# CJ Miles             183.0
# Delon Wright          65.0
# Demar Derozan         99.0
# Fred Vanvleet        116.0
# Jakob Poltl            1.0
# Jonas Valanciunas     32.0
# Kyle Lowry           266.0
# Lorenzo Brown          4.0
# Lucas Nogiera         54.0
# Malcolm Miller         8.0
# Nigel Hayes            2.0
# Norman Powell         54.0
# OG Anunoby            86.0
# Pascal Siakam         32.0
# Serge Ibaka          116.0
# Name: 3P, dtype: float64

# %%
new_df['Name'].unique()
# Out:
# array(['Demar Derozan', 'Kyle Lowry', 'OG Anunoby', 'Serge Ibaka',
#        'Jonas Valanciunas', 'Pascal Siakam', 'Jakob Poltl',
#        'Fred Vanvleet', 'Delon Wright', 'CJ Miles', 'Norman Powell',
#        'Lucas Nogiera', 'Lorenzo Brown', 'Malcolm Miller',
#        'Alfonzo Mckinnie', 'Bruno Cabaclo', 'Nigel Hayes'], dtype=object)

# %%
new_df["Name"].value_counts()
new_df.dtypes
# Out:
# Rk                       int64
# G                      float64
# Date            datetime64[ns]
# Age                      int64
# Home vs Away            object
# Opp                     object
# Win/Loss by:            object
# GS                      object
# 3P                     float64
# 3PA                    float64
# 3P%                    float64
# Time Rested             object
# Name                    object
# dtype: object

# %%
vals
# Out:
# Age
# 20     86.0
# 22      1.0
# 23     97.0
# 24    164.0
# 25    103.0
# 26      2.0
# 27      4.0
# 28    215.0
# 30    146.0
# 31    252.0
# 32     51.0
# Name: 3P, dtype: float64

# %%
# Age:
# Player age and Number of Three Pointers Attempted
new_df.groupby(['Age'])
age_df = new_df.groupby(['Age'])
vals = age_df['3P'].sum()
vals.plot.bar(x=age_df.count().index, y=['3P'], rot=0)
# Tell matplotlib where we would like to place each of our x axis headers
x_axis = np.arange(len(age_df['Age']))
# Give our chart some labels and a tile
plt.title("Player Age & Number of 3 Pointer Made 2017-2018")
plt.xlabel("Player Age")
plt.ylabel("Number of 3 Pointer Made")
plt.savefig("Player Age & Number of 3 Pointer Made 2017-2018")

# %%
# Looking at the relationship between the age of players
population_age = []
for age in vals:
    population_age.append(age)

sample_age = [103, 2,4,215]
population_age_mean = sum(population_age)/len(population_age)
stats.ttest_1samp(sample, population_age_mean)
# Out:
# Ttest_1sampResult(statistic=-116.82326129742009, pvalue=1.3828281791266792e-06)

# %%
players_name_group.count()
# Out:
#                    Rk   G  Date  Age  Home vs Away  Opp  Win/Loss by:  GS  3P  \
# Name
# Alfonzo Mckinnie   82  14    82   82            82   82            82  82  14
# Bruno Cabaclo      54   2    54   54            54   54            54  54   2
# CJ Miles           92  80    92   92            92   92            92  92  80
# Delon Wright       92  79    92   92            92   92            92  92  79
# Demar Derozan      92  90    92   92            92   92            92  92  90
# Fred Vanvleet      92  82    92   92            92   92            92  92  82
# Jakob Poltl        92  91    92   92            92   92            92  92  91
# Jonas Valanciunas  92  87    92   92            92   92            92  92  87
# Kyle Lowry         92  88    92   92            92   92            92  92  88
# Lorenzo Brown      92  18    92   92            92   92            92  92  18
# Lucas Nogiera      92  76    92   92            92   92            92  92  76
# Malcolm Miller     82  15    82   82            82   82            82  82  15
# Nigel Hayes        12   2    12   12            12   12            12  12   2
# Norman Powell      92  76    92   92            92   92            92  92  76
# OG Anunoby         92  84    92   92            92   92            92  92  84
# Pascal Siakam      92  91    92   92            92   92            92  92  91
# Serge Ibaka        92  86    92   92            92   92            92  92  86
#
#                    3PA  3P%  Time Rested
# Name
# Alfonzo Mckinnie    14    7           82
# Bruno Cabaclo        2    1           54
# CJ Miles            80   80           92
# Delon Wright        79   71           92
# Demar Derozan       90   83           92
# Fred Vanvleet       82   78           92
# Jakob Poltl         91    3           92
# Jonas Valanciunas   87   51           92
# Kyle Lowry          88   88           92
# Lorenzo Brown       18   11           92
# Lucas Nogiera       76   66           92
# Malcolm Miller      15   11           82
# Nigel Hayes          2    1           12
# Norman Powell       76   66           92
# OG Anunoby          84   75           92
# Pascal Siakam       91   69           92
# Serge Ibaka         86   84           92

# %%
# Finding the number of 3 pointers made by each players per games played
threes_per_player_df = pd.DataFrame({"3 Points Made": players_name_group.sum()['3P'],
                                     "3 Points Attempted": players_name_group.sum()['3PA'],
                                 "Number of Games Played": players_name_group.count()['Rk']})
threes_per_player_df['3 Points Made Per Game'] = threes_per_player_df['3 Points Made'] / threes_per_player_df['Number of Games Played']

threes_per_players_sorted = threes_per_player_df.sort_values('3 Points Made Per Game', ascending = False)
threes_per_players_sorted['3 Points Made Per Game'].plot.bar(color='blue')
plt.xlabel("Players")
plt.ylabel("3 Points Made Per Game")
plt.title("Number of 3 Pointers Made by Player per Games Played 2017-2018")
plt.tight_layout()
plt.savefig('Number 3 Pointers Made by Each Player Per Games Played.png')

# %%
# Print out the samples we want to look for. These players were either not on the Raptors roster in the 2016-2017 season 
# or was only on the roster for part of the season
print(players_group_df.loc['CJ Miles','3P'])
print(players_group_df.loc['Serge Ibaka','3P'])
print(players_group_df.loc['OG Anunoby', '3P'])
# Out:
# 183.0
# 116.0
# 86.0

# %%
players_group_df['3P']
# Out:
# Name
# Kyle Lowry           266.0
# CJ Miles             183.0
# Fred Vanvleet        116.0
# Serge Ibaka          116.0
# Demar Derozan         99.0
# OG Anunoby            86.0
# Delon Wright          65.0
# Lucas Nogiera         54.0
# Norman Powell         54.0
# Jonas Valanciunas     32.0
# Pascal Siakam         32.0
# Malcolm Miller         8.0
# Lorenzo Brown          4.0
# Alfonzo Mckinnie       3.0
# Nigel Hayes            2.0
# Jakob Poltl            1.0
# Bruno Cabaclo          0.0
# Name: 3P, dtype: float64

# %%
# understand how individual players impact the number of 3 pointers made and attempted
# which players scored fans the most free fries?
# show in a bar chart
players_group = new_df.groupby('Name').sum()
players_group_df = players_group.sort_values("3P", ascending = False)
players_group_df
players_group_df['3P'].plot.bar(color = 'blue');

plt.title("Number of 3 Pointers Made by Player per Games Played 2017-2018")
plt.ylabel("3 Points Made Per Game")
plt.tight_layout()
plt.savefig("Number of 3 Pointers Made by Each Player in the 2017-2018 Season.png")

# %%
# Looking at the relationship between the new players and the whole team roster
population = []
for x in players_group_df['3P']:
    population.append(x)

sample = [183, 116, 86]
population_mean = sum(population)/len(population)
stats.ttest_1samp(sample, population_mean)
# Out:
# Ttest_1sampResult(statistic=2.176029307403218, pvalue=0.16152020507547502)

# %% [markdown]
# # The Three Cells below displays the data from Danny Green, Kawhi Leonard, and Marc Gasol who joined the Raptors before the 2018-2019 Season

# %%
# Danny Green Data

green_df = pd.read_csv("danny green stats .csv")

# delete unwanted columns

green_df = green_df.drop (columns=[
    'FT', 'FTA', 'FT%', 'ORB','DRB', 'TRB', 'AST', 'STL', 
    'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm', 'Rk', 'G'])

# headings
green_df = green_df.rename(columns={"Unnamed: 5":"Home vs Away","Unnamed: 7":"Win/Loss by:"})
green_df['Home vs Away'].fillna("Home", inplace = True)
green_df['Home vs Away'] = green_df['Home vs Away'].replace(to_replace = "@", value = "Away")
# STEP 5 - Add Player 
green_df['Name'] = "Danny Green"

green_mean = green_df['3P'].mean()
green_3_percentage = green_df['3P'] / green_df['3PA'] * 100
print(f" Danny Green on average, makes {round(green_mean,2)} 3 pointers per game")
print(f" Danny Green's 3 point percentage is {green_3_percentage.mean()}")
# Out:
#  Danny Green on average, makes 2.26 3 pointers per game
#  Danny Green's 3 point percentage is 39.55845664583529

# %%
#Read CSV for Kawai Lenord
leonard_df = pd.read_csv("kawai Lenord stats.csv")

leonard_df = leonard_df.drop (columns=[
    'FT', 'FTA', 'FT%', 'ORB','DRB', 'TRB', 'AST', 'STL', 
    'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm', 'Rk', 'G'])

#  Add Player 
leonard_df['Name'] = "Kawai Leonard"
leonard_df = leonard_df.rename(columns={"Unnamed: 5":"Home vs Away","Unnamed: 7":"Win/Loss by:"})
leonard_df['Home vs Away'].fillna("Home", inplace = True)
leonard_df['Home vs Away'] = leonard_df['Home vs Away'].replace(to_replace = "@", value = "Away")
# headings
leonard_df = leonard_df.rename(columns={" ":"Home vs Away"," .1":"Win/Loss by:"})


leonard_mean = leonard_df['3P'].mean()
leonard_3_percentage = leonard_df['3P'] / leonard_df['3PA'] * 100
print(f" Kawhi Leonard on average, makes {round(leonard_mean,2)} 3 pointers per game")
print(f" Kawhi Leonard's 3 point percentage is {leonard_3_percentage.mean()}")
# Out:
#  Kawhi Leonard on average, makes 1.99 3 pointers per game
#  Kawhi Leonard's 3 point percentage is 34.509637188208615

# %%
#Read CSV for Marc Gasol

gasol_df = pd.read_csv("marc Gasol stats.csv")



gasol_df = gasol_df.drop (columns=[
    'FT', 'FTA', 'FT%', 'ORB','DRB', 'TRB', 'AST', 'STL', 
    'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-','MP', 'FG','FGA','FG%', 'Tm', 'Rk'])
gasol_df['Name'] = "Kawai Leonard"
gasol_df = gasol_df.rename(columns={"Unnamed: 5":"Home vs Away","Unnamed: 7":"Win/Loss by:"})
gasol_df['Home vs Away'].fillna("Home", inplace = True)
gasol_df['Home vs Away'] = gasol_df['Home vs Away'].replace(to_replace = "@", value = "Away")

#Player name 

gasol_df['Name'] = "Marc Gasol"


gasol_mean = gasol_df['3P'].mean()
gasol_3_percentage = gasol_df['3P'] / gasol_df['3PA'] * 100
print(f" Marc Gasol on average, makes {round(gasol_mean,2)} 3 pointers per game")
print(f" Marc Gasol's 3 point percentage is {gasol_3_percentage.mean()}")
# Out:
#  Marc Gasol on average, makes 1.28 3 pointers per game
#  Marc Gasol's 3 point percentage is 36.81639666175748

# %%
#Bar graph for danny green, kawhi leonard, and marc gasol
green_mean
leonard_mean
gasol_mean
new_players_names = ['Danny Green', 'Kawhi Leonard', 'Marc Gasol']
new_players_3pm_mean = [green_mean,leonard_mean,gasol_mean]
new_players_df = pd.DataFrame({"Player Names":new_players_names,
                              "3 Points Made Per Game": new_players_3pm_mean})

new_players_df=new_players_df.set_index("Player Names")

new_players_df.plot.bar(color = "blue")
plt.ylabel("3 Points Made Per Game")
plt.title("3 Pointers Made by New Players per Games Played 2017-2018")
plt.tight_layout()
plt.savefig("DannyGreen KawhiLeonard MarcGasol 3 points made")

# %%
players_group['3P%'] = players_group['3P'] *100/(players_group['3P'].sum())
players_group
# Out:
#                      Rk       G   Age     3P    3PA        3P%
# Name
# Alfonzo Mckinnie   3403   105.0  2050    3.0    9.0   0.267618
# Bruno Cabaclo      1485     3.0  1188    0.0    2.0   0.000000
# CJ Miles           3458  2540.0  2783  183.0  499.0  16.324710
# Delon Wright       3458  2470.0  2305   65.0  174.0   5.798394
# Demar Derozan      3458  3295.0  2576   99.0  322.0   8.831401
# Fred Vanvleet      3458  2947.0  2150  116.0  289.0  10.347904
# Jakob Poltl        3458  3448.0  2024    1.0    3.0   0.089206
# Jonas Valanciunas  3458  3058.0  2301   32.0   79.0   2.854594
# Kyle Lowry         3458  3136.0  2871  266.0  659.0  23.728814
# Lorenzo Brown      3458   115.0  2484    4.0   17.0   0.356824
# Lucas Nogiera      3458  2506.0  2208   54.0  193.0   4.817128
# Malcolm Miller     3403   120.0  1988    8.0   21.0   0.713649
# Nigel Hayes         126     7.0   276    2.0    2.0   0.178412
# Norman Powell      3458  2506.0  2208   54.0  193.0   4.817128
# OG Anunoby         3458  2830.0  1840   86.0  226.0   7.671722
# Pascal Siakam      3458  3376.0  2132   32.0  136.0   2.854594
# Serge Ibaka        3458  2981.0  2576  116.0  321.0  10.347904

# %%
players_group2 = players_group.loc[players_group["3P%"] > 5]
players_group2
# Out:
#                  Rk       G   Age     3P    3PA        3P%
# Name
# CJ Miles       3458  2540.0  2783  183.0  499.0  16.324710
# Delon Wright   3458  2470.0  2305   65.0  174.0   5.798394
# Demar Derozan  3458  3295.0  2576   99.0  322.0   8.831401
# Fred Vanvleet  3458  2947.0  2150  116.0  289.0  10.347904
# Kyle Lowry     3458  3136.0  2871  266.0  659.0  23.728814
# OG Anunoby     3458  2830.0  1840   86.0  226.0   7.671722
# Serge Ibaka    3458  2981.0  2576  116.0  321.0  10.347904

# %%
labels = players_group2.index
colors = ['red', 'black', 'green', 'blue', 'cyan', 'yellow', 'magenta', 'orange', 'purple', 'pink', "brown", 'gold', 'turquoise', 'maroon', 'beige', 'gray', 'lavender']
sizes = players_group2['3P%']
#fig1,ax1 = plt.subplots()
plt.figure(figsize=(10,10))
plt.pie(sizes, labels=labels, colors=colors, autopct = "%1.1f%%", shadow=True, startangle = 140);
plt.tight_layout()
#ax1.axis('equal')

# %%
# Calculate the number of games the raptors made over 12 threes 
dates_group = new_df.groupby(['Date'])

dates_group['3P'].sum() >= 12

dates_group.sum().loc[dates_group.sum()['3P'] >= 12, :]
dates_group_df = dates_group.count()
dates_group_sum = dates_group.sum()
dates_group.count()
# Out:
#             Rk   G  Age  Home vs Away  Opp  Win/Loss by:  GS  3P  3PA  3P%  \
# Date
# 2017-10-19  16  13   16            16   16            16  16  13   13    9
# 2017-10-21  16  13   16            16   16            16  16  13   13   11
# 2017-10-23  16  10   16            16   16            16  16  10   10    9
# 2017-10-25  16  11   16            16   16            16  16  11   11    8
# 2017-10-27  16  11   16            16   16            16  16  11   11   10
# ...         ..  ..  ...           ...  ...           ...  ..  ..  ...  ...
# 2018-04-27  13  10   13            13   13            13  13  10   10    7
# 2018-05-01  13  10   13            13   13            13  13  10   10    9
# 2018-05-03  13  13   13            13   13            13  13  13   13   11
# 2018-05-05  13   9   13            13   13            13  13   9    9    6
# 2018-05-07  13  13   13            13   13            13  13  13   13    8
#
#             Time Rested  Name
# Date
# 2017-10-19           16    16
# 2017-10-21           16    16
# 2017-10-23           16    16
# 2017-10-25           16    16
# 2017-10-27           16    16
# ...                 ...   ...
# 2018-04-27           13    13
# 2018-05-01           13    13
# 2018-05-03           13    13
# 2018-05-05           13    13
# 2018-05-07           13    13
#
# [92 rows x 12 columns]

# %%
# number of times the raptors made over 12 threes
numberof3s_scored = dates_group_sum.loc[dates_group_sum['3P'] >= 12, '3P'].count()
print(f' The Raptors made over 12 threes in the 2017-2018 season {numberof3s_scored} times.')
# Out:
#  The Raptors made over 12 threes in the 2017-2018 season 53 times.

# %%
# average 3 points percentages per game
average_3pm_total = dates_group.sum()['3P']/dates_group.sum()['3PA'] *100
average_3pm_total.mean()
dates_group_sum['3P'].sum()
# Out:
# 1121.0

# %%
dates_group.sum()['3P'].mean()
# Out:
# 12.184782608695652

# %%
dates_group.sum()['3PA'].mean()
# Out:
# 34.18478260869565

# %%
average_3pm_total.sum() / len(average_3pm_total)
# Out:
# 35.60746749055375

# %%
new_df['Home vs Away'].unique()
demar_df[['Date', 'Home vs Away']]
demar_df['Home vs Away'].unique()
# Out:
# array(['Home', 'Away'], dtype=object)

# %%
homeaway_3PM_group.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-122df8dd0939> in <module>
# ----> 1 homeaway_3PM_group.sum()
#
# NameError: name 'homeaway_3PM_group' is not defined

# %%
# Find out how many threes are made in 
homeaway_3PM = pd.DataFrame({
                            "Home vs Away": demar_df['Home vs Away'],
                            "3 Points Made": dates_group.sum()['3P'].values})
homeaway_3PM_group = homeaway_3PM.groupby(['Home vs Away'])

homeaway_3PM_group.mean().plot.bar(color = 'blue')

plt.xlabel("Game Types")
plt.ylabel("Average 3 Points Made")
plt.ylim(9,13)
plt.title("Game Types vs Average 3 Points Made 2017-2018")
plt.tight_layout()
plt.savefig("Game Types vs Average 3 Points Made.png")

# %%
homeaway_3PM_group.sum()
# Out:
#               3 Points Made
# Home vs Away
# Away                  540.0
# Home                  581.0

# %%
average_3pm_total
# Out:
# Date
# 2017-10-19    45.714286
# 2017-10-21    29.545455
# 2017-10-23    25.641026
# 2017-10-25    22.857143
# 2017-10-27    21.875000
#                 ...
# 2018-04-27    28.000000
# 2018-05-01    32.142857
# 2018-05-03    38.709677
# 2018-05-05    39.393939
# 2018-05-07    25.000000
# Length: 92, dtype: float64

# %%
# Pie Chart for Game Types vs Average 3 points made
homeaway_3PM_label = ['Away', 'Home']
homeaway_3PM_color = ['skyblue', 'lightgreen']
homeaway_3PM_sizes = homeaway_3PM_group.sum()
plt.pie(homeaway_3PM_sizes, labels = homeaway_3PM_label, colors = homeaway_3PM_color, autopct="%1.1f%%", shadow=True, startangle=140);

plt.tight_layout()
# Out:
# C:\Users\smartestpersonalive\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   """

# %%
# Find out the 3 point percentages in Home and Away games 
homeaway_3PPercent = pd.DataFrame({"Home vs Away": demar_df['Home vs Away'],
                                  "3 Point Percentage (%)": average_3pm_total.values})
homeaway_3PPercent_group = homeaway_3PPercent.groupby(['Home vs Away'])
homeaway_average_3PPercent = homeaway_3PPercent_group.mean()
homeaway_average_3PPercent.plot.bar(color='blue')
# chart labels
plt.xlabel("Game Types")
plt.ylabel("Average 3 Points Percentages (%)")
plt.ylim(31,38)

plt.title("Game Types vs Average 3 Points Percentages 2017-2018")
plt.tight_layout()
plt.savefig("Games Types vs Average 3 Points Percentages")

# %%
homeaway_3PPercent_label = ['Away', 'Home']
homeaway_3PPercent_color = ['lightblue','lightgreen']
homeaway_3PPercent_sizes = homeaway_3PPercent_group.sum()
plt.pie(homeaway_3PPercent_sizes, labels=homeaway_3PPercent_label, colors=homeaway_3PPercent_color, autopct="%1.1f%%", shadow=True, startangle=140)
plt.tight_layout()
# Out:
# C:\Users\smartestpersonalive\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   after removing the cwd from sys.path.

# %%
timerested_group.count()
timerested_group_count = timerested_group.count().drop(['N/A'])
timerested_group_count['3P']
# Out:
# Time Rested
# 1.0    162
# 2.0    641
# 3.0    176
# 4.0     59
# 6+      10
# Name: 3P, dtype: int64

# %%
timerested_group = new_df.groupby(['Time Rested'])
timerested_mean = timerested_group['3P'].mean().drop(['N/A'])

labels = ['1 Day Rest', '2 Days Rest', '3 Days Rest', '4 Days Rest', '6+ Days Rest']
colors = ['red', 'pink', 'blue', 'green', 'orange']
plt.pie(timerested_mean, labels = labels, colors = colors, autopct = '%1.1f%%', shadow=True, startangle=140)

plt.title("Average 3 Pointers Made by Number of Days Rest, 2017-2018")
plt.tight_layout()
plt.savefig("Average 3 Pointers Made by Number of Days Rest, 2017-2018")

# %%
timerested_group.count()
# Out:
#               Rk    G  Date  Age  Home vs Away  Opp  Win/Loss by:   GS   3P  \
# Time Rested
# 1.0          221  162   221  221           221  221           221  221  162
# 2.0          872  641   872  872           872  872           872  872  641
# 3.0          225  176   225  225           225  225           225  225  176
# 4.0           76   59    76   76            76   76            76   76   59
# 6+            15   10    15   15            15   15            15   15   10
# N/A           17   13    17   17            17   17            17   17   13
#
#              3PA  3P%  Name
# Time Rested
# 1.0          162  132   221
# 2.0          641  508   872
# 3.0          176  139   225
# 4.0           59   50    76
# 6+            10    7    15
# N/A           13    9    17

# %%
one_day_rested_df = pd.DataFrame({"Rested": "1 Day Rest",
                              "3 Points Made": one_day_rested })


two_days_rested_df = pd.DataFrame({"Rested": "2 Days Rest",
                                  "3 Points Made": two_days_rested})
three_days_rested_df = pd.DataFrame({"Rested": "3 Days Rest",
                                  "3 Points Made": three_days_rested})
four_days_rested_df = pd.DataFrame({"Rested": "4 Days Rest",
                                  "3 Points Made": four_days_rested})
five_days_rested_df = pd.DataFrame({"Rested": "5+ Days Rest",
                                  "3 Points Made": five_days_rested})

# %%
# Create a list that contains data sorted by number of days days rested
one_day_rested = new_df.loc[new_df['Time Rested'] ==1, '3P']
two_days_rested = new_df.loc[new_df['Time Rested'] == 2, '3P']
two_days_rested
three_days_rested = new_df.loc[new_df['Time Rested'] == 3, '3P']
four_days_rested = new_df.loc[new_df['Time Rested'] == 4, '3P']
five_days_rested = new_df.loc[new_df['Time Rested'] == "6+", '3P']

days_rested_list = [one_day_rested_df, two_days_rested_df, three_days_rested_df, four_days_rested_df, five_days_rested_df]
days_rested_list_df = pd.concat(days_rested_list)

# Create a boxplot to compare means
days_rested_list_df.boxplot("3 Points Made", by="Rested", figsize=(20,10))

# %%
#Quartile calculations 
quartiles = timerested_mean.quantile([0.25, 0.5, 0.75])
lowerq = quartiles[0.25]
median = [0.5]
upperq = quartiles[0.75]
iqr = upperq - lowerq

# %%
# Identify outliers
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f'Values below {lower_bound} could be outliers.')
print(f'Values above {upper_bound} could be outliers.')
# Out:
# Values below 0.9444733344889352 could be outliers.
# Values above 1.1715876042449103 could be outliers.

# %%
timerested_mean
# Out:
# Time Rested
# 1.0    1.086420
# 2.0    1.029641
# 3.0    1.130682
# 4.0    1.033898
# 6+     0.900000
# Name: 3P, dtype: float64

# %%
# Generate box plots 
fig1,ax1 = plt.subplots()
ax1.boxplot(timerested_mean)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b532759dc8>,
#   <matplotlib.lines.Line2D at 0x2b532777f08>],
#  'caps': [<matplotlib.lines.Line2D at 0x2b5327b6d48>,
#   <matplotlib.lines.Line2D at 0x2b5327b6988>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2b532777a48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b5327b65c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b532762cc8>],
#  'means': []}

# %%
BCE_bought = 46.09 * 150
BCE_sell = 53.53 * 150
print(BCE_bought)
print(BCE_sell)
print(BCE_sell - BCE_bought)
# Out:
# 6913.500000000001
# 8029.5
# 1115.999999999999

# %%
rbc_bought = 72.67 * 95
rbc_sell = 85.12 * 95
print(rbc_bought)
print(rbc_sell)
print(rbc_sell-rbc_bought)
# Out:
# 6903.650000000001
# 8086.400000000001
# 1182.75

# %%
# Out:
# 766.4499999999998

# %%
demar['Name'] = "Demar Derozan"
klo['Name'] = "Kyle Lowry"
anunoby['Name'] = "OG Anunoby"
demar_threepoint = demar[['Date', '3P', '3PA', '3P%']]
demar_threepoint
klo_threepoint = klo[['Date', '3P', '3PA', '3P%']]
anunoby_threepoint = anunoby[['Date', "3P", '3PA', '3P%']]

# %%
demar_kyle = pd.merge(demar_threepoint, klo_threepoint, on = "Date", suffixes = ("_Demar", "_Kyle"))

# %%
pd.merge(demar_kyle, anunoby_threepoint, on="Date", suffixes=("","Anunoby"))

# %%
number_daysrested_1617 = pd.read_csv("NumberDaysRested/Reg_Number_Days_Off_2016-2017.csv")
number_daysrested_1718 = pd.read_csv("NumberDaysRested/Reg_Number_Days_Off_2017-2018.csv")

# %%
threepoints_1617 = number_daysrested_1617 [["DAYS REST","3PM","3PA"]]

# %%
threepoints_1718 = number_daysrested_1718[["DAYS REST",'3PM','3PA']]
threepoints_1718

# %%
pd.merge(threepoints_1617, threepoints_1718, on = 'DAYS REST', suffixes = ("_16-17", "_17-18"))

# %%
threepoints_1617['3PM']

# %%
plt.scatter(threepoints_1617['3PA'],threepoints_1617['3PM'], marker='o')

# %%
threepoints_1617

# %%
colors = ['b', 'c', 'y', 'm', 'r', 'purple']
a = plt.scatter(threepoints_1617['3PM'],threepoints_1617['3PA'], marker='o', color = colors[0])


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(threepoints_1617['3PM'],threepoints_1617['3PA'])
lin_regress = slope*threepoints_1617['3PM'] + intercept
line_equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.plot(threepoints_1617['3PM'], lin_regress, color = 'r')

plt.annotate(line_equation, (4,22), color = 'r')

plt.grid()

# %%
colors = ['b', 'c', 'y', 'm', 'r', 'purple']
a = plt.scatter(threepoints_1617['3PM'][0],threepoints_1617['3PA'][0], marker='o', color = colors[0])
b = plt.scatter(threepoints_1617['3PM'][1],threepoints_1617['3PA'][1], marker='o', color = colors[1])
c = plt.scatter(threepoints_1617['3PM'][2],threepoints_1617['3PA'][2], marker='o', color = colors[2])
d = plt.scatter(threepoints_1617['3PM'][3],threepoints_1617['3PA'][3], marker='o', color = colors[3])
e = plt.scatter(threepoints_1617['3PM'][4],threepoints_1617['3PA'][4], marker='o', color = colors[4])
f = plt.scatter(threepoints_1617['3PM'][5],threepoints_1617['3PA'][5], marker='o', color = colors[5])

plt.legend((a,b,c,d,e,f),
           ('0 Days Rest', '1 Day Rest', '2 Days Rest', '3 Days Rest', '5 Days Rest', '6+ Days Rest'),
           scatterpoints=1,
           loc='lower left',
           ncol=3,
           fontsize=8)
plt.xlabel("3 Points Made")
plt.ylabel("3 Points Attempted")
plt.title("3PM vs 3PA for the 2016-2017 Season")


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(threepoints_1617['3PM'],threepoints_1617['3PA'])
lin_regress = slope*threepoints_1617['3PM'] + intercept
line_equation = f'y = {round(slope,2)}x + {round(intercept,2)}'

plt.plot(threepoints_1617['3PM'], lin_regress, color = 'r')

plt.annotate(line_equation, (4,22), color = 'r')

plt.grid()

# %%
x_axis = [1,2,3,4,5,6]
plt.bar(threepoints_1617['3PM'], threepoints_1617['3PA'], )
